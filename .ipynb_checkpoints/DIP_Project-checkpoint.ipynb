# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2
from numpy import linalg as LA
from skimage import data
from skimage.color import rgb2gray

# %%
img1=Image.open('./i1.jpeg').convert('L')
img2=Image.open('./i2.jpeg').convert('L')

# %%
orig_image = np.array(img1)
skewed_image = np.array(img2)

try:
    surf = cv2.xfeatures2d.SURF_create(500)
except Exception:
    surf = cv2.SIFT(500)
    
kp1,des1 = surf.detectAndCompute(orig_image, None)
kp2,des2 = surf.detectAndCompute(skewed_image, None)

FLANN_INDEX_KDTREE = 0
index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5)
search_params = dict(checks=50)
flann = cv2.FlannBasedMatcher(index_params, search_params)
matches = flann.knnMatch(des1,des2,k=2)

good = []
for m, n in matches:
    if m.distance < 0.7 * n.distance:
        good.append(m)

MIN_MATCH_COUNT = 10
if len(good) > MIN_MATCH_COUNT:
    src_pts = np.float32([kp1[m.queryIdx].pt for m in good]).reshape(-1, 1, 2)
    dst_pts = np.float32([kp2[m.trainIdx].pt for m in good]).reshape(-1, 1, 2)
    H1, mask = cv2.findHomography(src_pts, dst_pts, cv2.RANSAC, 5.0)

# %%
print(H1)
plt.figure(figsize=(5,5))
plt.imshow(orig_image)
plt.scatter(src_pts,dst_pts)
plt.show()
plt.figure(figsize=(5,5))
plt.imshow(skewed_image)
plt.scatter(src_pts,dst_pts)
plt.show()
# Out:
# [[ 9.56451895e-01 -1.07633156e-02  8.22158150e+00]
#  [ 2.78138009e-03  9.73684649e-01  6.10172552e+00]
#  [-3.07072559e-06 -1.47628775e-05  1.00000000e+00]]

# %%
img1=Image.open('./i1.jpeg').convert('L')
img2=Image.open('./i2.jpeg').convert('L')
img2=img2.resize(np.array(img1).T.shape)
a=np.array(img1)
b=np.array(img2)
print(a.shape)
print(b.shape)
sift=cv2.xfeatures2d.SIFT_create()
key_points=sift.detect(a)
pts1=np.array([x.pt for x in key_points],dtype=np.float32)
#print(pts1)
pts2,status,_=cv2.calcOpticalFlowPyrLK(a,b,pts1,None)
status=status.reshape(status.shape[0])
pts1=pts1[status == 1]
pts2=pts2[status == 1]
H, mask = cv2.findHomography(pts1,pts2, cv2.RANSAC, 5.0)
print(H)
plt.figure(figsize=(10,10))
plt.imshow(a)
plt.scatter(pts1[:,0],pts1[:,1])
plt.show()
plt.figure(figsize=(10,10))
plt.imshow(b)
plt.scatter(pts2[:,0],pts2[:,1])
plt.show()
# Out:
# (1280, 913)
# (1280, 913)
# [[ 9.72352086e-01 -1.20925461e-02  8.70609316e+00]
#  [ 1.53866269e-03  9.73930248e-01  6.36300159e+00]
#  [-3.09535794e-06 -1.48956776e-05  1.00000000e+00]]

# %%
# def homography(img1, img2, visualize=False):
#     """
#     Finds Homography matrix from Image1 to Image2.
#         Two images should be a plane and can change in viewpoint

#     :param img1: Source image
#     :param img2: Target image
#     :param visualize: Flag to visualize the matched pixels and Homography warping
#     :return: Homography matrix. (or) Homography matrix, Visualization image - if visualize is True
#     """
#     sift = cv2.xfeatures2d.SIFT_create()
#     kp1, desc1 = sift.detectAndCompute(img1, None)
#     kp2, desc2 = sift.detectAndCompute(img2, None)

#     index_params = dict(algorithm=FLANN_INDEX_KDTREE)
#     # number of times the trees in the index should be recursively traversed
#     # Higher values gives better precision, but also takes more time
#     sch_params = dict(checks=50)
#     flann = cv2.FlannBasedMatcher(index_params, sch_params)

#     matches = flann.knnMatch(desc1, desc2, k=2)
#     logging.debug('{} matches found'.format(len(matches)))

#     # select good matches
#     matches_arr = []
#     good_matches = []
#     for m, n in matches:
#         if m.distance < GOOD_MATCH_THRESHOLD * n.distance:
#             good_matches.append(m)
#         matches_arr.append(m)

#     if len(good_matches) < MIN_MATCH_COUNT:
#         raise (Exception('Not enough matches found'))
#     else:
#         logging.debug('{} of {} are good matches'.format(len(good_matches), len(matches)))

#     src_pts = [kp1[m.queryIdx].pt for m in good_matches]
#     src_pts = np.array(src_pts, dtype=np.float32).reshape((-1, 1, 2))
#     dst_pts = [kp2[m.trainIdx].pt for m in good_matches]
#     dst_pts = np.array(dst_pts, dtype=np.float32).reshape((-1, 1, 2))

#     homo, mask = cv.findHomography(src_pts, dst_pts, cv.RANSAC, 5)

#     if visualize:
#         res = visualize_homo(img1, img2, kp1, kp2, matches, homo, mask)
#         return homo, res

#     return homo

# %%
# img1=Image.open('./i1.jpeg')
# img2=Image.open('./i2.jpeg')
# print(homography(np.array(img1),np.array(img2),False))

# %%
# def find_correspondence_points(img1, img2):
#     sift = cv2.xfeatures2d.SIFT_create()

#     # find the keypoints and descriptors with SIFT
#     kp1, des1 = sift.detectAndCompute(
#         cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY), None)
#     kp2, des2 = sift.detectAndCompute(
#         cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY), None)

#     # Find point matches
#     FLANN_INDEX_KDTREE = 0
#     index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5)
#     search_params = dict(checks=50)
#     flann = cv2.FlannBasedMatcher(index_params, search_params)
#     matches = flann.knnMatch(des1, des2, k=2)

#     # Apply Lowe's SIFT matching ratio test
#     good = []
#     for m, n in matches:
#         if m.distance < 0.8 * n.distance:
#             good.append(m)

#     src_pts = np.asarray([kp1[m.queryIdx].pt for m in good])
#     dst_pts = np.asarray([kp2[m.trainIdx].pt for m in good])

#     # Constrain matches to fit homography
#     retval, mask = cv2.findHomography(src_pts, dst_pts, cv2.RANSAC, 100.0)
#     mask = mask.ravel()

#     # We select only inlier points
#     pts1 = src_pts[mask == 1]
#     pts2 = dst_pts[mask == 1]

#     return pts1.T, pts2.T

# %%
# a,b=find_correspondence_points(np.array(img1),np.array(img2))

# %%
# plt.figure(figsize=(15,15))
# plt.imshow(np.array(img1))
# # plt.scatter(a,b)
# plt.show()

# %%
img1=Image.open('./i1.jpeg').convert('L')
a=[[100,123],
[132,124],
[168,124],
[100,145],
[132,145],
[168,145],
[100,168],
[132,168],
[168,168],
[100,190],
[132,190],
[168,190],
[100,212],
[132,212],
[168,212],
[202,212],
[236,212]]
a=np.array(a)
plt.figure(figsize=(15,15))
plt.imshow(np.array(img1),cmap='gray')
plt.scatter(a[:,0],a[:,1])
plt.show()

# %%
x=a.shape[0]
u=np.hstack((a,np.ones((x,1))))
u=u.T
final=np.matmul(H,u)
final=final.T
for i in range(0,x):
    final[i][0]=final[i][0]/final[i][2]
    final[i][1]=final[i][1]/final[i][2]
    final[i][2]=final[i][2]/final[i][2]
i2 = np.array(img2)
plt.figure(figsize=(15,15))
plt.imshow(np.array(img2),cmap='gray')
plt.scatter(final[:,0],final[:,1])
plt.show()

# %%
img=np.array(img1)
binaryImg1 = (img < 200).astype(np.uint8)
plt.figure(figsize=(15,15))
plt.imshow(binaryImg1,cmap='gray')

# %%
img=np.array(img2)
binaryImg2 = (img < 200).astype(np.uint8)
#print(binaryImg2[np.int(final[1][0])][np.int(final[1][1])])
#print(np.int(final[0][0]),np.int(final[0][1]))
plt.figure(figsize=(15,15))
plt.imshow(binaryImg2,cmap='gray')
plt.scatter(final[:,0],final[:,1])
plt.show()

# %%
# ret,tp = cv2.threshold(np.array(img2),127,255,cv2.THRESH_BINARY)
tp  = (np.array(img2) < 200).astype(np.uint8)
im = np.array(tp)
kernel = np.ones((11,11),np.uint8)
opening = cv2.morphologyEx(im, cv2.MORPH_OPEN, kernel)
# closing = cv2.morphologyEx(opening, cv2.MORPH_CLOSE, kernel)
plt.figure(figsize=(15,15))
plt.imshow(im,cmap='gray')
plt.show()
plt.figure(figsize=(15,15))
plt.imshow(opening,cmap='gray')
plt.scatter(final[:,0],final[:,1])
plt.show()
print(final)
# plt.figure(figsize=(15,15))
# plt.imshow(closing,cmap='gray')
# plt.show()
# binaryImg3 = get_binarize_img(im)
# binaryImg3 = np.array(binaryImg3);
# binaryImg3 = 255-binaryImg3
# d = binaryImg3.shape
# for i in range(d[0]):
#     for j in range(d[1]):
#         if binaryImg3[i][j]>100:
#             binaryImg3[i][j]=255
#         if binaryImg3[i][j]<=100:
#             binaryImg3[i][j]=0
            
cnt =0
# t =5
# print(np.array(binaryImg3)[138,128])
final = np.uint8(np.around(final))
# print(binaryImg3[final[t,0]][final[t,1]])
# print(final.shape[0])
# #final = final.astype(np.int8)
mn=11
for i in range(final.shape[0]):
    flag=0
    for j in range(mn):
        #print(binaryImg3[np.int(final[i][0])][np.uint8(final[i][1])])
        if flag==0 and final[i][1]-j >=0 and opening[final[i][1]-j][final[i][0]] !=0:
            opening[final[i][1]-j][final[i][0]] = 0
            print(i,final[i][0],final[i][1])
            cnt += 1
            flag=1
        elif flag ==0 and final[i][1]+j < opening.shape[0] and opening[final[i][1]+j][final[i][0]] !=0:
            opening[final[i][1]+j][final[i][0]] = 0
            print(i,final[i][0],final[i][1])
            cnt += 1
            flag = 1
        elif flag ==0 and final[i][0]-j >=0 and opening[final[i][1]][final[i][0]-j] !=0:
            opening[final[i][1]][final[i][0]-j] = 0
            print(i,final[i][0],final[i][1])
            cnt += 1
            flag =1
        elif flag ==0 and final[i][0]+j < opening.shape[1] and opening[final[i][1]][final[i][0]+j] !=0:
            opening[final[i][1]][final[i][0]+j] = 0
            print(i,final[i][0],final[i][1])
            cnt += 1
            flag =1
print(cnt)

# plt.figure(figsize=(15,15))
# plt.imshow(img1,cmap='gray')
# plt.show()
# plt.figure(figsize=(15,15))
# plt.imshow(img2,cmap='gray')
# plt.show()
# plt.figure(figsize=(15,15))
# plt.imshow(binaryImg3,cmap='gray')
# print()
# plt.scatter(final[t,0],final[t,1])
# plt.show()
# Out:
# [[104.6781081  126.58138828   1.        ]
#  [135.86355356 127.62132506   1.        ]
#  [170.96645985 127.6911033    1.        ]
#  [104.44580196 148.10247946   1.        ]
#  [135.65156498 148.166551     1.        ]
#  [170.7654576  148.23864669   1.        ]
#  [104.20277319 170.61692601   1.        ]
#  [135.41923439 170.68325616   1.        ]
#  [170.54516756 170.75789334   1.        ]
#  [103.97015458 192.16696445   1.        ]
#  [135.19685569 192.2354579    1.        ]
#  [170.33431363 192.31252932   1.        ]
#  [103.73738297 213.73117613   1.        ]
#  [134.97433072 213.80183573   1.        ]
#  [170.123321   213.88134457   1.        ]
#  [203.3268097  213.95645258   1.        ]
#  [236.53731451 214.03157646   1.        ]]
# 0 105 127
# 4 136 148
# 7 135 171
# 11 170 192
# 13 135 214
# 5

# %%
img1=Image.open('./i1.jpeg').convert('L')
incorrect_options=[[132,124],
[168,124],
[100,145],
[168,145],
[100,168],
[168,168],
[100,190],
[132,190],
[100,212],
[132,212],
[202,212],
[236,212]]
correct_option = [[100,123],[132,145],[132,168],[168,190],[168,212]]
incorrect_options=np.array(incorrect_options)
correct_option = np.array(correct_option)
plt.figure(figsize=(15,15))
plt.imshow(np.array(img1),cmap='gray')
plt.scatter(incorrect_options[:,0],incorrect_options[:,1],c='red')
plt.scatter(correct_option[:,0],correct_option[:,1],c='g')
plt.show()

# %%
x=incorrect_options.shape[0]
u_ic=np.hstack((incorrect_options,np.ones((x,1))))
u_ic=u_ic.T
final_ic=np.matmul(H,u_ic)
final_ic=final_ic.T
for i in range(0,x):
    final_ic[i][0]=final_ic[i][0]/final_ic[i][2]
    final_ic[i][1]=final_ic[i][1]/final_ic[i][2]
    final_ic[i][2]=final_ic[i][2]/final_ic[i][2]
    
    
x=correct_option.shape[0]
u_cc=np.hstack((correct_option,np.ones((x,1))))
u_cc=u_cc.T
final_cc=np.matmul(H,u_cc)
final_cc=final_cc.T
for i in range(0,x):
    final_cc[i][0]=final_cc[i][0]/final_cc[i][2]
    final_cc[i][1]=final_cc[i][1]/final_cc[i][2]
    final_cc[i][2]=final_cc[i][2]/final_cc[i][2]
    
    
i2 = np.array(img2)
plt.figure(figsize=(15,15))
plt.imshow(np.array(img2),cmap='gray')
plt.scatter(final_ic[:,0],final_ic[:,1],c='red')
plt.scatter(final_cc[:,0],final_cc[:,1],c='g')
plt.show()

# %%
tp  = (np.array(img2) < 200).astype(np.uint8)
im = np.array(tp)
kernel = np.ones((11,11),np.uint8)
opening = cv2.morphologyEx(im, cv2.MORPH_OPEN, kernel)
# closing = cv2.morphologyEx(opening, cv2.MORPH_CLOSE, kernel)
plt.figure(figsize=(15,15))
plt.imshow(im,cmap='gray')
plt.show()
plt.figure(figsize=(15,15))
plt.imshow(opening,cmap='gray')
plt.scatter(final_ic[:,0],final_ic[:,1],c='red')
plt.scatter(final_cc[:,0],final_cc[:,1],c='g')
plt.show()
# plt.figure(figsize=(15,15))
# plt.imshow(closing,cmap='gray')
# plt.show()
# binaryImg3 = get_binarize_img(im)
# binaryImg3 = np.array(binaryImg3);
# binaryImg3 = 255-binaryImg3
# d = binaryImg3.shape
# for i in range(d[0]):
#     for j in range(d[1]):
#         if binaryImg3[i][j]>100:
#             binaryImg3[i][j]=255
#         if binaryImg3[i][j]<=100:
#             binaryImg3[i][j]=0
            
cnt =0
# t =5
# print(np.array(binaryImg3)[138,128])
final_ic = np.uint8(np.around(final_ic))
final_cc = np.uint8(np.around(final_cc))
# print(binaryImg3[final[t,0]][final[t,1]])
# print(final.shape[0])
# #final = final.astype(np.int8)
mn=11
for i in range(final_cc.shape[0]):
    flag=0
    for j in range(mn):
        #print(binaryImg3[np.int(final[i][0])][np.uint8(final[i][1])])
        if flag==0 and final_cc[i][1]-j >=0 and opening[final_cc[i][1]-j][final_cc[i][0]] !=0:
            opening[final_cc[i][1]-j][final_cc[i][0]] = 0
            print(i,final_cc[i][0],final_cc[i][1])
            cnt += 1
            flag=1
        elif flag ==0 and final_cc[i][1]+j < opening.shape[0] and opening[final_cc[i][1]+j][final_cc[i][0]] !=0:
            opening[final_cc[i][1]+j][final_cc[i][0]] = 0
            print(i,final_cc[i][0],final_cc[i][1])
            cnt += 1
            flag = 1
        elif flag ==0 and final_cc[i][0]-j >=0 and opening[final_cc[i][1]][final_cc[i][0]-j] !=0:
            opening[final_cc[i][1]][final_cc[i][0]-j] = 0
            print(i,final_cc[i][0],final_cc[i][1])
            cnt += 1
            flag =1
        elif flag ==0 and final_cc[i][0]+j < opening.shape[1] and opening[final_cc[i][1]][final_cc[i][0]+j] !=0:
            opening[final_cc[i][1]][final_cc[i][0]+j] = 0
            print(i,final_cc[i][0],final_cc[i][1])
            cnt += 1
            flag =1
print("Total Correct option: ",cnt)

cnti=0
for i in range(final_ic.shape[0]):
    flag=0
    for j in range(mn):
        #print(binaryImg3[np.int(final[i][0])][np.uint8(final[i][1])])
        if flag==0 and final_ic[i][1]-j >=0 and opening[final_ic[i][1]-j][final_ic[i][0]] !=0:
            opening[final_ic[i][1]-j][final_ic[i][0]] = 0
            print(i,final_ic[i][0],final_ic[i][1])
            cnti += 1
            flag=1
        elif flag ==0 and final_ic[i][1]+j < opening.shape[0] and opening[final_ic[i][1]+j][final_ic[i][0]] !=0:
            opening[final_ic[i][1]+j][final_ic[i][0]] = 0
            print(i,final_ic[i][0],final_ic[i][1])
            cnti += 1
            flag = 1
        elif flag ==0 and final_ic[i][0]-j >=0 and opening[final_ic[i][1]][final_ic[i][0]-j] !=0:
            opening[final_ic[i][1]][final_ic[i][0]-j] = 0
            print(i,final_ic[i][0],final_ic[i][1])
            cnti += 1
            flag =1
        elif flag ==0 and final_ic[i][0]+j < opening.shape[1] and opening[final_ic[i][1]][final_ic[i][0]+j] !=0:
            opening[final_ic[i][1]][final_ic[i][0]+j] = 0
            print(i,final_ic[i][0],final_ic[i][1])
            cnti += 1
            flag =1
print("Total Incorrect Options: ",cnti)

print("Total Score: ", 4*cnt - cnti)
# Out:
# 0 105 127
# 1 136 148
# 2 135 171
# 3 170 192
# Total Correct option:  4
# 9 135 214
# Total Incorrect Options:  1
# Total Score:  15
